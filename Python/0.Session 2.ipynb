# %%
1.Comparators
2.Boolean Operators
3.Condition
4.Define Function
5.looping: for/while::

# %%
1.Comparators

# %%
Comparators
1.== :Equalto
2.> :Greater than
3.>= :Greater than equalto
4.< : Less than
5.<= : Less than equalto
6.!= : not equal to

# %%
print("Equalto 1==2=",1==2)
print("Greater than 2<7=",2<7)
print("Greater than equal to 2<=2=",2<=2)
print("Less than 1>2=",1>2)
print("Less than equal to 1>=2 =",1>=2)
print("Not equal to 1!=2 =",1!=2)
# Out:
# Equalto 1==2= False
# Greater than 2<7= True
# Greater than equal to 2<=2= True
# Less than 1>2= False
# Less than equal to 1>=2 = False
# Not equal to 1!=2 = True

# %%
2.Boolean Operators

# %%
Boolean Operators
1.and=Evaluates to True if both statements are true,otherwise evaluates to False.
2.or=Evaluates to True if either of the statements is true, otherwise evaluates to False.
3.not=Evaluates to the opposite of the statement.

Truth Table
True and True is True
True and False is False
False and True is False
False and False is False

True or True is True
True or False is True
False or True is True
False or False is False

Not True is False
Not False is True

# %%
print("And:",(1<2)and (2>3))
print("or:",(1<2)or (2>3))
print("not:",not ((1<2)or (2>3)))
# Out:
# And: False
# or: True
# not: False

# %%
3.Conditionals

# %%
age=45

if age<30:
    print("<30")
elif (age >=30) and (age <=40):
    print(">=30 and <=40")
else:
    print(">40")
# Out:
# >40

# %%
age=45

if age<30:print("<30")
elif (age >=30) and (age <=40):print(">=30 and <=40")
else:print(">40")
# Out:
# >40

# %%
4. Function

# %%
#Define Function
def first_func():
    print("hello")

#Call function
first_func()
# Out:
# hello

# %%
#Define Function with positional parameter
def first_func(p):
    print(p)

#Call function
first_func("Hello")
# Out:
# Hello

# %%
#Define Function with keyword parameter
def first_func(x,y):
    z=x+y
    return z

#Call function
first_func(x=2,y=4)
# Out:
# 6

# %%
lambda argument:expression

# %%
first_func1=lambda x,y:x+y
#Call function
first_func1(x=2,y=4)
# Out:
# 6

# %%
*args is used in function definitions to allow the function to accept any number of positional arguments.
The term "args" stands for "arguments", and the asterisk (*) is what allows multiple arguments to be passed

# %%
def sum_numbers(x, *args):
    total = x
    for num in args:
        total += num
    return total

# Call the function
result = sum_numbers(2, 4, 6, 8)
print(result)  # Output: 20
# Out:
# 20

# %%
**kwargs stands for "keyword arguments". It allows a function to accept any number of named arguments
(i.e., arguments passed using key=value syntax). 
These arguments are captured as a dictionary inside the function.

# %%
def display_info(**kwargs):
    for key, value in kwargs.items():
        print(f"{key}: {value}")

# Call the function
display_info(name="Shashi", age=30, job="Data Analyst Programmer")
# Out:
# name: Shashi
# age: 30
# job: Data Analyst Programmer

# %%
For loop:-

# %%
seq=[1,2,3,4,5]
for item in seq:
    print(item)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for x in range(0,6):print(x)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
seq=["Shashi","Mohan","Ram"]
for i in seq:
    print(i)
# Out:
# Shashi
# Mohan
# Ram

# %%
#square of number
x=[1,2,3]
for num in x:
    k=num**2   
    print(k)
# Out:
# 1
# 4
# 9

# %%
x=[1,2,3]
result=[num**2 for num in x]
result
# Out:
# [1, 4, 9]

# %%
def squarenum(x):
    return x*x

squarenum(2)
# Out:
# 4

# %%
while loop:A while loop in Python is used to repeatedly execute a block of code as long as a given condition is True.

# %%
i = 1
while i < 5:
    print('i is: {}'.format(i))
    i = i+1
# Out:
# i is: 1
# i is: 2
# i is: 3
# i is: 4
