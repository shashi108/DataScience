# %% [markdown]
# # Data Types
# Numbers
# Strings
# Lists
# Dictionaries
# Tuples
# Sets

# %%
var="hello"
print(var)
# Out:
# hello

# %%
x=4
y=5
print(x)
print(y)
# Out:
# 4
# 5

# %%
1.Number
Addition(+)
Subtraction(-)
Multiplication (*)
Division (/)
Remainder(%)
Power(**)
Expression

# %%
1+2
# Out:
# 3

# %%
6-4
# Out:
# 2

# %%
3**4
# Out:
# 81

# %%
2. string

# %%
'My name is shashi'
# Out:
# 'My name is shashi'

# %%
"My name is shashi"
# Out:
# 'My name is shashi'

# %%
"My name is 'shashi' "
# Out:
# "My name is 'shashi' "

# %%
k='Python'
k
# Out:
# 'Python'

# %%
k[0]
# Out:
# 'P'

# %%
k[0:3]
# Out:
# 'Pyt'

# %%
k[1]
# Out:
# 'y'

# %%
'shashi'+'kumar'
# Out:
# 'shashikumar'

# %%
first = 'I'
second = 'love'
third = 'Python'
sentence = first + ' ' + second + ' ' +third + '.'
print(sentence)
# Out:
# I love Python.

# %%
python Array:-
1. list
2.Set
3.Tuple
4. Dictionary

# %%
num=[1,4,5]
num
# Out:
# [1, 4, 5]

# %%
char=['a','kumar']
char
# Out:
# ['a', 'kumar']

# %%
num_char=[1,2,'kumar']
num_char
# Out:
# [1, 2, 'kumar']

# %%
nested list:
nest=[lst1[list2[list3]]]

# %%
#nest=[list1[lit2[list3]]]
nest = [12,3,[,4,5,['King','Boy']]]
nest
# Out:
# [1, 2, 3, [4, 5, ['King', 'Boy']]]

# %%
nest[3]
# Out:
# [4, 5, ['King', 'Boy']]

# %%
nest[3][1]
# Out:
# 5

# %%
4.Dictionaries
Hold key-value pairs called items.
dictionary_name = {key_1: value_1, key_N: value_N}

# %%
#Assign Dictionary
d={'k1':[1,2,3],'k2':[4,5,6]}
d
# Out:
# {'k1': [1, 2, 3], 'k2': [4, 5, 6]}

# %%
d['k1']
# Out:
# [1, 2, 3]

# %%
a=[1,1,1,1,3,4]    [],(),{}
a
# Out:
# [1, 1, 1, 1, 3, 4]

# %%
b={1,1,1,1,3,4}
b
# Out:
# {1, 3, 4}

# %%
c=set([1,1,1,1,3,4])
c
# Out:
# {1, 3, 4}

# %%
tuple1 = ("abc", 34, True, 40, "male")
tuple1
# Out:
# ('abc', 34, True, 40, 'male')

# %%
tuple1[1]=4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 tuple1[1]=4
#
# TypeError: 'tuple' object does not support item assignment
