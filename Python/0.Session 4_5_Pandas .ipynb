# %% [markdown]
# # Pandas

# %%
1.Create DataFrame
>Using Lists
>Using Dictionary
2.Copy Dataframe
3.Select/Keep columns
4.Create /add new columns
5.Rename Columns
6.Sorting DataFrame
7.Select rows or columns
8.Drop Rows/ Columns
9.Reset/ Set index


10.Filter based on conditional operators
>Using Basic method
>Using query function
11.Missing Data
12.Group by operation
13.Merging Concept : Concatation,Append,Merge,join
# Out:
#   Cell In[1], line 1
#     1.Create DataFrame
#      ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# #### Library

# %%
#pip install pandas
import pandas as pd

# %% [markdown]
# ### 1.a Create a DataFrame from Lists

# %%
list1=[['a',1],['b',2],['c',3]]
pd.DataFrame(list1,columns=['Number','Character'])
# Out:
#   Number  Character
# 0      a          1
# 1      b          2
# 2      c          3

# %% [markdown]
# ### 1.b Create a DataFrame from Dict of ndarrays / Lists

# %%
Age=[12,15,56,89]
Salary=[6000,7000,8000,9000]
Name=['A','B','C','D']
index=['first','second','third','four']
df=pd.DataFrame({'Name': Name,'Age':Age,'Salary':Salary},index=index)
df
# Out:
#        Name  Age  Salary
# first     A   12    6000
# second    B   15    7000
# third     C   56    8000
# four      D   89    9000

# %% [markdown]
# ### 2.Copy DataFrame

# %%
df1=df.copy()
df1
# Out:
#        Name  Age  Salary
# first     A   12    6000
# second    B   15    7000
# third     C   56    8000
# four      D   89    9000

# %% [markdown]
# ### 3.Select/Keep columns

# %%
#Dataframe[columnnames]
df['Name']
# Out:
# first     A
# second    B
# third     C
# four      D
# Name: Name, dtype: object

# %%
df3=df[['Name','Age']]
df3
# Out:
#        Name  Age
# first     A   12
# second    B   15
# third     C   56
# four      D   89

# %% [markdown]
# ### 4.Create /add new columns

# %%
df['new']=df['Age']+df['Salary']
df
# Out:
#        Name  Age  Salary   new
# first     A   12    6000  6012
# second    B   15    7000  7015
# third     C   56    8000  8056
# four      D   89    9000  9089

# %% [markdown]
# ### 5.Rename Columns

# %%
#inplace=True:overwrite the existing dataset
label={'Name':'Student Name','Age':'Student Age'}
df.rename(columns=label,inplace=True)

# %%
df
# Out:
#        Student Name  Student Age  Salary   new
# first             A           12    6000  6012
# second            B           15    7000  7015
# third             C           56    8000  8056
# four              D           89    9000  9089

# %% [markdown]
# ### 6.Sorting DataFrame

# %% [markdown]
# DataFrame.sort_values(by, axis=0, ascending=True, inplace=False, kind=’quicksort’, na_position=’last’)

# %%
df.sort_values(['Salary','new'],ascending=[False,False],inplace=True)

# %%
df
# Out:
#        Student Name  Student Age  Salary   new
# four              D           89    9000  9089
# third             C           56    8000  8056
# second            B           15    7000  7015
# first             A           12    6000  6012

# %% [markdown]
# ### 7.Select Rows/Columns

# %% [markdown]
# Select rows using 2 methods: <br>
# 1.iloc=select row based on index label <br>
# 2.loc=select row based on index position

# %%
df
# Out:
#        Student Name  Student Age  Salary   new
# four              D           89    9000  9089
# third             C           56    8000  8056
# second            B           15    7000  7015
# first             A           12    6000  6012

# %%
#select first row by index name
df.loc['first']
# Out:
# Student Name       A
# Student Age       12
# Salary          6000
# new             6012
# Name: first, dtype: object

# %%
#select first row by row name
df.iloc[0]
# Out:
# Student Name       D
# Student Age       89
# Salary          9000
# new             9089
# Name: four, dtype: object

# %%
## Select 2 & 3rd row
df.iloc[[1,2]]
# Out:
#        Student Name  Student Age  Salary   new
# third             C           56    8000  8056
# second            B           15    7000  7015

# %%
#Select 3rd row and column 'Name' and 'Age'
df.iloc[2,[0,1]]
# Out:
# Student Name     B
# Student Age     15
# Name: second, dtype: object

# %%
#Select 3rd,4th row and column 'Name' and 'Age'
df.iloc[[2,3],[0,1]]
# Out:
#        Student Name  Student Age
# second            B           15
# first             A           12

# %%
#Select 3rd,4th row and column 'Name' and 'Age'
df.loc[['third','four'],['Student Name','Student Age']]
# Out:
#       Student Name  Student Age
# third            C           56
# four             D           89

# %% [markdown]
# ### 8.Drop Rows/Columns

# %% [markdown]
# DataFrame.drop(labels=None, *, axis=0, index=None, columns=None, level=None, inplace=False, errors='raise')

# %%
df.drop('third',axis=0)
# Out:
#        Student Name  Student Age  Salary   new
# four              D           89    9000  9089
# second            B           15    7000  7015
# first             A           12    6000  6012

# %%
# axis=1: operation column wise
# axis=0 :operation row wise
#dataframe.drop(index label,axis=1)
df.drop('Student Age',axis=1)
# Out:
#        Student Name  Salary   new
# four              D    9000  9089
# third             C    8000  8056
# second            B    7000  7015
# first             A    6000  6012

# %%
df.columns
# Out:
# Index(['Student Name', 'Student Age', 'Salary', 'new'], dtype='object')

# %%
df.columns[0]
# Out:
# 'Student Name'

# %%
df.describe()
# Out:
#        Student Age       Salary          new
# count     4.000000     4.000000     4.000000
# mean     43.000000  7500.000000  7543.000000
# std      36.651512  1290.994449  1326.151072
# min      12.000000  6000.000000  6012.000000
# 25%      14.250000  6750.000000  6764.250000
# 50%      35.500000  7500.000000  7535.500000
# 75%      64.250000  8250.000000  8314.250000
# max      89.000000  9000.000000  9089.000000

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### 9.Reset/ Set index

# %%
#Reset index
df.reset_index()
# Out:
#     index Student Name  Student Age  Salary   new
# 0    four            D           89    9000  9089
# 1   third            C           56    8000  8056
# 2  second            B           15    7000  7015
# 3   first            A           12    6000  6012

# %%
#set column same is the index
df.set_index('Student Name')
# Out:
#               Student Age  Salary   new
# Student Name
# D                      89    9000  9089
# C                      56    8000  8056
# B                      15    7000  7015
# A                      12    6000  6012

# %% [markdown]
# ### 10.Filter based on conditional operators

# %%
#condition:Return boolean result
df['Salary']>7000
# Out:
# four       True
# third      True
# second    False
# first     False
# Name: Salary, dtype: bool

# %%
#dataframe[condition]:Return only true row value
df[df['Salary']>7000]
# Out:
#       Student Name  Student Age  Salary   new
# four             D           89    9000  9089
# third            C           56    8000  8056

# %%
#Select salary and student name where salary >7000
df[df['Salary']>7000][['Salary','Student Name']]
# Out:
#        Salary Student Name
# four     9000            D
# third    8000            C

# %%
#select only those observation which salary >7000 and age >56
df[(df['Salary']>7000) & (df['Student Age'] >=15)]
# Out:
#       Student Name  Student Age  Salary   new
# four             D           89    9000  9089
# third            C           56    8000  8056

# %%
#select only those observation which salary >7000 or age >56
df[(df['Salary']>7000) | (df['Student Age'] >=15)]
# Out:
#        Student Name  Student Age  Salary   new
# four              D           89    9000  9089
# third             C           56    8000  8056
# second            B           15    7000  7015

# %% [markdown]
# ### Query function

# %%
df.query('Salary ==8000')
# Out:
#       Student Name  Student Age  Salary   new
# third            C           56    8000  8056

# %%
df.query('Salary in [8000,7000]')
# Out:
#        Student Name  Student Age  Salary   new
# third             C           56    8000  8056
# second            B           15    7000  7015

# %%
df.query('Salary not in [8000,7000]')
# Out:
#       Student Name  Student Age  Salary   new
# four             D           89    9000  9089
# first            A           12    6000  6012

# %%
df.query('Salary >= 5000 & Salary <=8000')
# Out:
#        Student Name  Student Age  Salary   new
# third             C           56    8000  8056
# second            B           15    7000  7015
# first             A           12    6000  6012

# %% [markdown]
# ### 11.Missing Data

# %%
import numpy as np

# %%
d=pd.DataFrame({'A':[1,2,np.nan],'B':[5,np.nan,np.nan],'C':[1,2,3]})
d
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
#True/False for all value:if missing show True
d.isna()
# Out:
#        A      B      C
# 0  False  False  False
# 1  False   True  False
# 2   True   True  False

# %%
#Show Column wise which columns have nan values(even 1 nan is enough)
d.isna().any()
# Out:
# A     True
# B     True
# C    False
# dtype: bool

# %%
#drop missing columns
d.dropna(axis=1)
# Out:
#    C
# 0  1
# 1  2
# 2  3

# %%
#drop missing row:(thresh=n)::Keep rows ,if atlest 'n' non-missing is there .
d.dropna(thresh=2)
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2

# %% [markdown]
# #### Fill missing value
# dataframe.fillna(value='fill')

# %%
d
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
#fill missing value with 0 value
d.fillna(value=0)
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  0.0  2
# 2  0.0  0.0  3

# %%
#fill missing value with mean value in column 'A'
d['A'].fillna(value=d['A'].mean())
# Out:
# 0    1.0
# 1    2.0
# 2    1.5
# Name: A, dtype: float64

# %% [markdown]
# ### 12.Group by opration

# %%
Name=['A','B','A','C','B']
Salary=[1000,2000,4000,5000,600]
g=pd.DataFrame({'Name':Name,'Salary':Salary})
g
# Out:
#   Name  Salary
# 0    A    1000
# 1    B    2000
# 2    A    4000
# 3    C    5000
# 4    B     600

# %%
group=g.groupby('Name')

# %%
#Average Salary of each Name
group.mean()
# Out:
#       Salary
# Name
# A     2500.0
# B     1300.0
# C     5000.0

# %%
# Count of each Name
group.count()
# Out:
#       Salary
# Name
# A          2
# B          2
# C          1

# %%
# Sum of each Name
group.sum()
# Out:
#       Salary
# Name
# A       5000
# B       2600
# C       5000

# %%
group.describe()
# Out:
#      Salary
#       count    mean          std     min     25%     50%     75%     max
# Name
# A       2.0  2500.0  2121.320344  1000.0  1750.0  2500.0  3250.0  4000.0
# B       2.0  1300.0   989.949494   600.0   950.0  1300.0  1650.0  2000.0
# C       1.0  5000.0          NaN  5000.0  5000.0  5000.0  5000.0  5000.0

# %% [markdown]
# ### 13.Merging Concept : Concatation,Append,Merge,join

# %%
ID=[100,101,103,104,108]
Salary=[5000,6000,2000,4000,9000]
df1=pd.DataFrame({'ID':ID,'Salary':Salary})
df1
# Out:
#     ID  Salary
# 0  100    5000
# 1  101    6000
# 2  103    2000
# 3  104    4000
# 4  108    9000

# %%
ID=[100,101,105,107]
Age=[24,25,34,55]
df2=pd.DataFrame({'ID':ID,'Age':Age})
df2
# Out:
#     ID  Age
# 0  100   24
# 1  101   25
# 2  105   34
# 3  107   55

# %% [markdown]
# #### Concatation
# concat(objs, axis=0, join='outer', join_axes=None, ignore_index=False, keys=None, levels=None, names=None, verify_integrity=False, sort=None, copy=True)

# %%
#Append data frames vertically
pd.concat([df1,df2],sort=False)
# Out:
#     ID  Salary   Age
# 0  100  5000.0   NaN
# 1  101  6000.0   NaN
# 2  103  2000.0   NaN
# 3  104  4000.0   NaN
# 4  108  9000.0   NaN
# 0  100     NaN  24.0
# 1  101     NaN  25.0
# 2  105     NaN  34.0
# 3  107     NaN  55.0

# %% [markdown]
# #### Merge function
# merge(left, right, how='inner', on=None, left_on=None, right_on=None, left_index=False, right_index=False, sort=False, suffixes=('_x', '_y'), copy=True, indicator=False, validate=None)
#
# how : {'left', 'right', 'outer', 'inner'}, default 'inner' Type of merge to be performed.
#
#     * left: use only keys from left frame, similar to a SQL left outer join;
#       preserve key order.
#     * right: use only keys from right frame, similar to a SQL right outer join;
#       preserve key order.
#     * outer: use union of keys from both frames, similar to a SQL full outer
#       join; sort keys lexicographically.
#     * inner: use intersection of keys from both frames, similar to a SQL inner
#       join; preserve the order of the left keys.

# %% [markdown]
# #### Left join

# %%
pd.merge(df1,df2,how='left',on='ID')
# Out:
#     ID  Salary   Age
# 0  100    5000  24.0
# 1  101    6000  25.0
# 2  103    2000   NaN
# 3  104    4000   NaN
# 4  108    9000   NaN

# %% [markdown]
# ### Right join

# %%
pd.merge(df1,df2,how='right',on='ID')
# Out:
#     ID  Salary  Age
# 0  100  5000.0   24
# 1  101  6000.0   25
# 2  105     NaN   34
# 3  107     NaN   55

# %% [markdown]
# #### Join Function
# join(other, on=None, how='left', lsuffix='', rsuffix='', sort=False)
#
# how : {'left', 'right', 'outer', 'inner'}, default 'left' How to handle the operation of the two objects.
#
#     * left: use calling frame's index (or column if on is specified)
#     * right: use `other`'s index.
#     * outer: form union of calling frame's index (or column if on isspecified) with `other`'s index, and sort it.
#       lexicographically.
#     * inner: form intersection of calling frame's index (or column ifon is specified) with `other`'s index, preserving              the order of the calling's one.

# %%
df1.join(df2,how='left',sort=True,lsuffix='_l',rsuffix='_r')
# Out:
#    ID_l  Salary   ID_r   Age
# 0   100    5000  100.0  24.0
# 1   101    6000  101.0  25.0
# 2   103    2000  105.0  34.0
# 3   104    4000  107.0  55.0
# 4   108    9000    NaN   NaN

# %%
df1.join(df2,how='inner',sort=True,lsuffix='_l',rsuffix='_r')
# Out:
#    ID_l  Salary  ID_r  Age
# 0   100    5000   100   24
# 1   101    6000   101   25
# 2   103    2000   105   34
# 3   104    4000   107   55

# %%
df1.merge(df2,how='inner', left_index=True, right_index=True, sort=True, suffixes=('_l', '_r'))
# Out:
#    ID_l  Salary  ID_r  Age
# 0   100    5000   100   24
# 1   101    6000   101   25
# 2   103    2000   105   34
# 3   104    4000   107   55

# %%
pd.merge(df1,df2,how='inner',on='ID')
# Out:
#     ID  Salary  Age
# 0  100    5000   24
# 1  101    6000   25
